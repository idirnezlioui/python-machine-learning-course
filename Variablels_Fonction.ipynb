# %% [markdown]
# # 🐍 Les Bases de Python - Variables et Fonctions (1)

# %% [markdown]
# ## 1 Variables et Opérations
#
# En Python, il existe **4 grands types de variables** :
#
# | Type   | Description               |
# |--------|---------------------------|
# | `int`  | Nombre entier             |
# | `float`| Nombre décimal            |
# | `str`  | Chaîne de caractères      |
# | `bool` | Booléen (Vrai ou Faux)    |

# %% [markdown]
# ##  Opérations arithmétiques
#
# | Type   | Description               |
# |--------|---------------------------|
# | `==`  | égalite            |
# | `!=`| Difference            |
# | `<=`  | Inferieur ou égale      |
# | `>=` | Supperieur ou éale     |

# %% [markdown]
# ## 2 Fonctions
#
# En Python, une **fonction** est un bloc de code réutilisable conçu pour exécuter une tâche spécifique.
# Les fonctions permettent de **structurer le code**, d’éviter les répétitions et de le rendre plus **lisible** et **modulaire**.
#
# ---
#
# ###  Définir une fonction
#
# La meilleure façon de créer une fonction est d’utiliser la structure suivante : **def**
#
# ### fonction avec Return
# La commande *return* permet de renvoyer une valeur à l’endroit où la fonction a été appelée.

# %% [markdown]
# ### Exercice
#
# Modifiez la fonction `e_potentielle` définie plus haut pour retourner une valeur indiquant si `l'energie` calculée est **supérieure** ou **inférieur** a une `energie_limite` passée en tant que 4eme argument
